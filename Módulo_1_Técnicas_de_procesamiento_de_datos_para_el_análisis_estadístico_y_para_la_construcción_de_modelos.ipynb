# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('ds_salaries.csv', index_col='Unnamed: 0')
df.tail()
# Out:
#      work_year experience_level employment_type      job_title  salary  \
# 602       2022               SE              FT  Data Engineer  154000
# 603       2022               SE              FT  Data Engineer  126000
# 604       2022               SE              FT   Data Analyst  129000
# 605       2022               SE              FT   Data Analyst  150000
# 606       2022               MI              FT   AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602             USD         154000                 US           100
# 603             USD         126000                 US           100
# 604             USD         129000                 US             0
# 605             USD         150000                 US           100
# 606             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# ...

# %% [markdown]
# # B. Explora las variables y familiarízate con su significado.

# %% [markdown]
# ## 1. Identifica la cantidad de datos y variables presentes.

# %%
df.keys()
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.count()
# Out:
# work_year             607
# experience_level      607
# employment_type       607
# job_title             607
# salary                607
# salary_currency       607
# salary_in_usd         607
# employee_residence    607
# remote_ratio          607
# company_location      607
# company_size          607
# dtype: int64

# %% [markdown]
# ## 2. Clasifica las variables de acuerdo a su tipo y escala de medición.

# %% [markdown]
# ### Datos categóricos/cualitativos
#
# **Escala nominal**: work_year, employment_type, job_title, salary_currency, employee_residence, company_location.
#
# **Escala ordinal**: experience_level, remote_ratio, company_size.
#
# ### Datos numéricos/cuantitativos
#
# **Escala de razón**: salary, salary_in_usd.

# %%
cualitativas = ["work_year","experience_level", "employment_type", "job_title", "salary_currency", "employee_residence", "remote_ratio", "company_location", "company_size"]
cuantitativas = ["salary", "salary_in_usd"]

# %% [markdown]
# # C. Exploración de la base de datos

# %% [markdown]
# ## 1. Calcula medidas estadísticas

# %% [markdown]
# ### Variables cuantitativas
# - Medidas de tendencia central: promedio, media, mediana y moda de los datos.
#
# - Medidas de dispersión: rango: máximo - mínimo, varianza, desviación estándar.

# %%
df[cuantitativas].describe()
# Out:
#              salary  salary_in_usd
# count  6.070000e+02     607.000000
# mean   3.240001e+05  112297.869852
# std    1.544357e+06   70957.259411
# min    4.000000e+03    2859.000000
# 25%    7.000000e+04   62726.000000
# 50%    1.150000e+05  101570.000000
# 75%    1.650000e+05  150000.000000
# max    3.040000e+07  600000.000000

# %%
df[cuantitativas].mode()
# Out:
#    salary  salary_in_usd
# 0   80000       100000.0
# 1  100000            NaN

# %% [markdown]
# ### Variables cualitativas
# - Tabla de distribución de frecuencia
#
# - Moda

# %%
pd.crosstab(df['work_year'], 'Freq')
# Out:
# col_0      Freq
# work_year
# 2020         72
# 2021        217
# 2022        318

# %%
pd.crosstab(df['employment_type'], 'Freq')
# Out:
# col_0            Freq
# employment_type
# CT                  5
# FL                  4
# FT                588
# PT                 10

# %%
pd.crosstab(df['job_title'], 'Freq')
# Out:
# col_0                                     Freq
# job_title
# 3D Computer Vision Researcher                1
# AI Scientist                                 7
# Analytics Engineer                           4
# Applied Data Scientist                       5
# Applied Machine Learning Scientist           4
# BI Data Analyst                              6
# Big Data Architect                           1
# Big Data Engineer                            8
# Business Data Analyst                        5
# Cloud Data Engineer                          2
# Computer Vision Engineer                     6
# Computer Vision Software Engineer            3
# Data Analyst                                97
# Data Analytics Engineer                      4
# Data Analytics Lead                          1
# Data Analytics Manager                       7
# Data Architect                              11
# Data Engineer                              132
# Data Engineering Manager                     5
# ...

# %%
pd.crosstab(df['salary_currency'], 'Freq')
# Out:
# col_0            Freq
# salary_currency
# AUD                 2
# BRL                 2
# CAD                18
# CHF                 1
# CLP                 1
# CNY                 2
# DKK                 2
# EUR                95
# GBP                44
# HUF                 2
# INR                27
# JPY                 3
# MXN                 2
# PLN                 3
# SGD                 2
# TRY                 3
# USD               398

# %%
pd.crosstab(df['employee_residence'], 'Freq')
# Out:
# col_0               Freq
# employee_residence
# AE                     3
# AR                     1
# AT                     3
# AU                     3
# BE                     2
# BG                     1
# BO                     1
# BR                     6
# CA                    29
# CH                     1
# CL                     1
# CN                     1
# CO                     1
# CZ                     1
# DE                    25
# DK                     2
# DZ                     1
# EE                     1
# ES                    15
# FR                    18
# GB                    44
# GR                    13
# HK                     1
# HN                     1
# HR                     1
# HU                     2
# IE                     1
# IN                    30
# IQ                     1
# IR                     1
# IT                     4
# JE                     1
# JP                     7
# KE                     1
# LU                     1
# ...

# %%
pd.crosstab(df['company_location'], 'Freq')
# Out:
# col_0             Freq
# company_location
# AE                   3
# AS                   1
# AT                   4
# AU                   3
# BE                   2
# BR                   3
# CA                  30
# CH                   2
# CL                   1
# CN                   2
# CO                   1
# CZ                   2
# DE                  28
# DK                   3
# DZ                   1
# EE                   1
# ES                  14
# FR                  15
# GB                  47
# GR                  11
# HN                   1
# HR                   1
# HU                   1
# IE                   1
# IL                   1
# IN                  24
# IQ                   1
# IR                   1
# IT                   2
# JP                   6
# KE                   1
# LU                   3
# MD                   1
# MT                   1
# MX                   3
# MY                   1
# NG                   2
# NL                   4
# ...

# %%
pd.crosstab(df['experience_level'], 'Freq')
# Out:
# col_0             Freq
# experience_level
# EN                  88
# EX                  26
# MI                 213
# SE                 280

# %%
pd.crosstab(df['remote_ratio'], 'Freq')
# Out:
# col_0         Freq
# remote_ratio
# 0              127
# 50              99
# 100            381

# %%
pd.crosstab(df['company_size'], 'Freq')
# Out:
# col_0         Freq
# company_size
# L              198
# M              326
# S               83

# %%
df[cualitativas].mode()
# Out:
#    work_year experience_level employment_type       job_title salary_currency  \
# 0       2022               SE              FT  Data Scientist             USD
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M

# %% [markdown]
# ## 2. Explora los datos usando herramientas de visualización

# %% [markdown]
# ### Variables cuantitativas:
# - Medidas de posición: cuartiles, outlier (valores atípicos), boxplots
#
# - Análisis de distribución de los datos (Histogramas). Identificar si tiene forma simétrica o asimétrica.

# %%
# sns.boxplot(data=df['salary'], orient='h')
df.boxplot(column='salary')

# %%
# sns.boxplot(data=df['salary_in_usd'], orient='h')
df.boxplot(column='salary_in_usd')

# %%
salary_std= df['salary'].std()
salary_outliers = df.loc[(df['salary'] > 3 * salary_std) | (df['salary'] < -3 * salary_std), ['salary']]
salary_outliers
# Out:
#        salary
# 7    11000000
# 102  11000000
# 136   7000000
# 137   8500000
# 177  30400000
# 263   4900000
# 285   7000000
# 384   6000000

# %%
salary_outliers.count()
# Out:
# salary    8
# dtype: int64

# %%
salary_std= df['salary_in_usd'].std()
salary_in_usd_outliers = df.loc[(df['salary_in_usd'] > 3 * salary_std) | (df['salary_in_usd'] < -3 * salary_std), ['salary_in_usd']]
salary_in_usd_outliers
# Out:
#      salary_in_usd
# 1           260000
# 25          325000
# 33          450000
# 37          250000
# 63          412000
# 74          235000
# 78          270000
# 93          276000
# 97          450000
# 115         225000
# 138         220000
# 141         240000
# 157         423000
# 160         230000
# 167         250000
# 173         235000
# 224         225000
# 225         416000
# 231         256000
# 252         600000
# 309         242000
# 321         220110
# 337         243900
# 342         224000
# 398         215300
# 416         260000
# 421         241000
# 444         215300
# 472         220000
# 477         220000
# 482         324000
# 483         216000
# 486         230000
# 519         380000
# 523         405000
# 532         214000
# 534         266400
# 535         213120
# 582         220110
# 592         230000

# %%
salary_in_usd_outliers.count()
# Out:
# salary_in_usd    40
# dtype: int64

# %%
plt.hist(df['salary'])
plt.show()

# %%
plt.hist(df['salary_in_usd'])
plt.show()

# %% [markdown]
# ### Variables categóricas:
# - Distribución de los datos (diagramas de barras, diagramas de pastel)

# %%
cualitativas
# Out:
# ['work_year',
#  'experience_level',
#  'employment_type',
#  'job_title',
#  'salary_currency',
#  'employee_residence',
#  'remote_ratio',
#  'company_location',
#  'company_size']

# %%
df.groupby(['work_year'])['work_year'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['work_year'])['work_year'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['experience_level'])['experience_level'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['experience_level'])['experience_level'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['employment_type'])['employment_type'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['employment_type'])['employment_type'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['job_title'])['job_title'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['job_title'])['job_title'].count().plot.bar(y = 'count', figsize = (10,5))
plt.show()

# %%
df.groupby(['salary_currency'])['salary_currency'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['salary_currency'])['salary_currency'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['employee_residence'])['employee_residence'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['employee_residence'])['employee_residence'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['remote_ratio'])['remote_ratio'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['remote_ratio'])['remote_ratio'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['company_location'])['company_location'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['company_location'])['company_location'].count().plot.bar(y = 'count')
plt.show()

# %%
df.groupby(['company_size'])['company_size'].count().plot.pie(y = 'count', autopct='%1.0f%%')
plt.show()
df.groupby(['company_size'])['company_size'].count().plot.bar(y = 'count')
plt.show()

# %% [markdown]
# ## 3. Identifica problemas de calidad de datos (registros duplicados, valores faltantes, outliers, etc).

# %% [markdown]
# Valores faltantes.
#
# No hay ningún valor faltante

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# Registros duplicados.
#
# Existen 42 registros duplicados

# %%
df[df.duplicated()]
# Out:
#      work_year experience_level employment_type                  job_title  \
# 217       2021               MI              FT             Data Scientist
# 256       2021               MI              FT              Data Engineer
# 331       2022               SE              FT               Data Analyst
# 332       2022               SE              FT               Data Analyst
# 333       2022               SE              FT               Data Analyst
# 353       2022               SE              FT             Data Scientist
# 362       2022               SE              FT               Data Analyst
# 363       2022               SE              FT               Data Analyst
# 370       2022               SE              FT             Data Scientist
# 374       2022               MI              FT              ETL Developer
# 377       2022               SE              FT              Data Engineer
# ...

# %%
df.duplicated().sum()
# Out:
# 42

# %% [markdown]
# # D. Preparación de los datos:

# %% [markdown]
# ## 1. Selecciona el conjunto de datos a utilizar.

# %% [markdown]
# - Decide qué conjunto de datos se utilizará. Identifica variables objetivo. En caso necesario, explica por qué se incluyeron o excluyeron variables.
#
# - Maneja datos categóricos: transforma a datos numéricos si es necesario.
#
# - En caso de necesidad de recorte de datos (atípicos, faltantes, duplicados, etc), explica el motivo de la reducción.
#
# - Maneja apropiadamente datos atípicos.

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
sns.barplot(x = df['work_year'],y = df['salary_in_usd'])
plt.show()

# %%
sns.barplot(x = df['experience_level'],y = df['salary_in_usd'])
plt.show()

# %% [markdown]
# **Experience_level.**
#
# EN Entry-level / Junior MI Mid-level / Intermediate SE Senior-level / Expert EX Executive-level / Director
# - Parece haber una relación entre el nivel de experiencia y el salario, por lo que se decidió incluir esta variable al modelo.
# - Como podría esperarse, aparentemente el salario aumenta según el nivel de experiencia (a excepción del nivel Director del cual no se cuentan datos)

# %%
sns.barplot(x = df['employment_type'],y = df['salary_in_usd'])
plt.show()

# %% [markdown]
# **Employment_type.**
#
# PT Part-time FT Full-time CT Contract FL Freelance
# -
# - Como podría esperarse, aparentemente el salario aumenta según el nivel de experiencia (a excepción del nivel Director del cual no se cuentan datos)

# %%
sns.barplot(x = df['job_title'],y = df['salary_in_usd'])
plt.show()

# %%
sns.barplot(x = df['salary_currency'],y = df['salary_in_usd'])
plt.show()

# %%
sns.barplot(x = df['employee_residence'],y = df['salary_in_usd'])
plt.show()

# %%
sns.barplot(x = df['remote_ratio'],y = df['salary_in_usd'])
plt.show()

# %%
sns.barplot(x = df['company_location'],y = df['salary_in_usd'])
plt.show()

# %%
sns.barplot(x = df['company_size'],y = df['salary_in_usd'])
plt.show()

# %% [markdown]
# **Variables excluidas**
# - salary
# - salary_currency
#
# Debido a que ambos atributos denotan distintos tipos de medición, incluirlos en el modelo no es conveniente. Decidiendo únicamente dejar como atributo cuantitativo y objetivo **_salary_in_usd_** el cual representa los dos excluidos pero en una misma escala.
#
# **Variables incluidas**
# - work_year,
# - experience_level,
# - employment_type,
# - job_title,
# - salary_currency,
# - employee_residence,
# - remote_ratio,
# - company_location,
# - company_size
#
# Tras una comparación de las variables anteriores con salary_in_usd, todas las variables categóricas demuestran distinción de salario en cada uno de sus niveles, por lo que se decidió utilizarlos.
#
# **Variable Objetivo**
# - salary_in_usd
#
# Se decidió utilizar salary_in_usd como variable objetivo con el objetivo de encontrar las condiciones que hacen que una persona especialista en analizar datos tenga un mejor suelo.

# %% [markdown]
# ## Transformación de datos

# %% [markdown]
# ### Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# ordinales: remote_ratio, experience_level, company_size

enc = OrdinalEncoder()
enc.fit(df[["experience_level","company_size"]])
df_transformed = pd.DataFrame()
# df_transformed[['salary_in_usd']] = df[['salary_in_usd']]
df_transformed[["experience_level","company_size"]] = enc.transform(df[["experience_level","company_size"]])
df_transformed['remote_ratio'] = df['remote_ratio']
# df[["experience_level","company_size"]] = enc.transform(df[["experience_level","company_size"]])
df_transformed
# Out:
#      experience_level  company_size  remote_ratio
# 0                 2.0           0.0             0
# 1                 3.0           2.0             0
# 2                 3.0           1.0            50
# 3                 2.0           2.0             0
# 4                 3.0           0.0            50
# ..                ...           ...           ...
# 602               3.0           1.0           100
# 603               3.0           1.0           100
# 604               3.0           1.0             0
# 605               3.0           1.0           100
# 606               2.0           0.0           100
#
# [607 rows x 3 columns]

# %% [markdown]
# ### One Hot Encoding

# %%
'''

# define data
work_year_array = np.asarray(df[['work_year']])
employment_type_array = np.asarray(df[['employment_type']])
job_title_array = np.asarray(df[['job_title']])
salary_currency_array = np.asarray(df[['salary_currency']])
employee_residence_array = np.asarray(df[['employee_residence']])
company_location_array = np.asarray(df[['company_location']])

# define one hot encoding
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
# transform data

work_year_matrix = encoder.fit_transform(work_year_array)
employment_type_matrix = encoder.fit_transform(employment_type_array)
job_title_matrix = encoder.fit_transform(job_title_array)
employee_residence_matrix = encoder.fit_transform(employee_residence_array)
company_location_matrix = encoder.fit_transform(company_location_array)

# df_transformed = pd.get_dummies()

columnsToEncode = ['work_year']
encoder.fit(df[columnsToEncode])
pd.concat([df.drop(columnsToEncode, 1), pd.DataFrame(encoder.transform(df[columnsToEncode]))], axis=1).reindex()
'''

from sklearn.preprocessing import OneHotEncoder

# Escala nominal: work_year, employment_type, job_title, salary_currency, employee_residence, company_location.

work_year = pd.get_dummies(df.work_year, prefix='year')
employment_type = pd.get_dummies(df.employment_type, prefix='employment')
job_title = pd.get_dummies(df.job_title, prefix='job_title')
employee_residence = pd.get_dummies(df.employee_residence, prefix='employee_residence')
company_location = pd.get_dummies(df.company_location, prefix='company_location')

df_transformed = pd.concat([df_transformed, work_year, employment_type, job_title, employee_residence, company_location], axis=1)

# %% [markdown]
# ### Resultado Final

# %%
df_transformed
# Out:
#      experience_level  company_size  remote_ratio  year_2020  year_2021  \
# 0                 2.0           0.0             0          1          0
# 1                 3.0           2.0             0          1          0
# 2                 3.0           1.0            50          1          0
# 3                 2.0           2.0             0          1          0
# 4                 3.0           0.0            50          1          0
# ..                ...           ...           ...        ...        ...
# 602               3.0           1.0           100          0          0
# 603               3.0           1.0           100          0          0
# 604               3.0           1.0             0          0          0
# 605               3.0           1.0           100          0          0
# 606               2.0           0.0           100          0          0
#
#      year_2022  employment_CT  employment_FL  employment_FT  employment_PT  \
# ...

# %% [markdown]
# ## 2. Transforma los datos en caso necesario.

# %% [markdown]
# - Revisa si es necesario discretizar los datos
#
# - Revisa si es necesario escalar y normalizar los datos
#
# - Construye atributos si es conveniente

# %% [markdown]
# # E. Reformatea/reestructura los datos si es necesario
